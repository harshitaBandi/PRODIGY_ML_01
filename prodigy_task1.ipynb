# %%
import pandas as pd

# Load the data from the provided CSV files
train_df = pd.read_csv("/content/train.csv")
test_df = pd.read_csv("/content/test.csv")
sample_submission_df = pd.read_csv("/content/sample_submission.csv")

# Display basic information about the dataframes
print("Train data:")
print(train_df.info())

print("\nTest data:")
print(test_df.info())

print("\nSample Submission data:")
print(sample_submission_df.info())

# Example: Display the first few rows of the dataframes
print("\nFirst few rows of Train data:")
print(train_df.head())

print("\nFirst few rows of Test data:")
print(test_df.head())

print("\nFirst few rows of Sample Submission data:")
print(sample_submission_df.head())

# Example: Save the modified dataframes to new CSV files
train_df.to_csv("train_modified.csv", index=False)
test_df.to_csv("test_modified.csv", index=False)
sample_submission_df.to_csv("sample_submission_modified.csv", index=False)
# Out:
# Train data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...
